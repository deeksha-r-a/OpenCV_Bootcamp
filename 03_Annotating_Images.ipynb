# %% [markdown]
# # <font style="color:black">Annotating Images</font>
#
# Covered:
#
# * Draw lines
# * Draw circles
# * Draw rectangles
# * Add text

# %%
import os
import cv2
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from zipfile import ZipFile
from urllib.request import urlretrieve
matplotlib.rcParams['figure.figsize'] = (9.0, 9.0)
# %matplotlib inline

# %% [markdown]
# ##  <font style="color:black">Download Assets</font>

# %%
def download_and_unzip(url, save_path):
    print(f"Downloading and extracting assests....", end="")

    urlretrieve(url, save_path)

    try:
        with ZipFile(save_path) as z:
            z.extractall(os.path.split(save_path)[0])

        print("Done")

    except Exception as e:
        print("\nInvalid file.", e)

# %%
URL = r"https://www.dropbox.com/s/48hboi1m4crv1tl/opencv_bootcamp_assets_NB3.zip?dl=1"

asset_zip_path = os.path.join(os.getcwd(), "opencv_bootcamp_assets_NB3.zip")

if not os.path.exists(asset_zip_path):
    download_and_unzip(URL, asset_zip_path)
# Out:
# Downloading and extracting assests....Done

# %% [markdown]
# # Read and Display

# %%
image = cv2.imread("Apollo_11_Launch.jpg", cv2.IMREAD_COLOR)
plt.imshow(image[:, :, ::-1])

# %% [markdown]
# ## <font style="color:black">Drawing a Line</font>

# %%
imageLine = image.copy()
cv2.line(imageLine, (400, 550), (800, 550), (0, 0, 255), thickness=5, lineType=cv2.LINE_AA);

# Display the image
plt.imshow(imageLine[:,:,::-1])

# %% [markdown]
# ## <font style="color:black">Drawing a Circle</font>

# %%
imageCircle = image.copy()

cv2.circle(imageCircle, (600,400), 300, (255, 0, 255), thickness=5, lineType=cv2.LINE_AA);

plt.imshow(imageCircle[:,:,::-1])

# %% [markdown]
# ## <font style="color:black">Drawing a Rectangle</font>

# %%
imageRectangle = image.copy()
cv2.rectangle(imageRectangle, (450, 50), (750, 650), (0, 255, 255), thickness=5, lineType=cv2.LINE_8)
plt.imshow(imageRectangle[:, :, ::-1])

# %% [markdown]
# ## <font style="color:black">Adding Text</font>

# %%
imageText = image.copy()
text = "It had successfully taken off"
fontScale = 2.3
fontFace = cv2.FONT_HERSHEY_PLAIN
fontColor = (0, 255, 0)
fontThickness = 2
cv2.putText(imageText, text, (200, 700), fontFace, fontScale, fontColor, fontThickness, cv2.LINE_AA);
plt.imshow(imageText[:, :, ::-1])
